# %% [markdown]
# # V12 – Praxis: Lösungen
#
# Lösungen zu den Fill-in-Blanks und der Mini-Challenge aus [../02_praxis.ipynb](../02_praxis.ipynb).

# %% [markdown]
# ## Fill-in-Blank 1 – Prompt-Template

# %%
rolle = "Python-Tutor"
kontext = "Anfaenger-Kurs, 1. Semester"
aufgabe = "Erklaere f-Strings"
format_wunsch = "2 Saetze + 1 Beispiel"

prompt = f"""Rolle: {rolle}
Kontext: {kontext}
Aufgabe: {aufgabe}
Format: {format_wunsch}"""

print(prompt)
# Out:
# Rolle: Python-Tutor
# Kontext: Anfaenger-Kurs, 1. Semester
# Aufgabe: Erklaere f-Strings
# Format: 2 Saetze + 1 Beispiel

# %% [markdown]
# ## Fill-in-Blank 2 – Eingabe normieren

# %%
rohe_eingabe = "  Vorschubgeschwindigkeit  \n"
normiert = rohe_eingabe.strip().lower()
print(repr(normiert))
# Out:
# 'vorschubgeschwindigkeit'

# %% [markdown]
# ## Fill-in-Blank 3 – Datenblatt-Prompt

# %%
vorlage = "Fasse das Datenblatt zu {WERKSTOFF} zusammen. Zielgruppe: {ZWECK}."
werkstoff = "S235JR"
zweck = "Konstruktions-Entwurf einer Rahmen-Schweissbaugruppe"

prompt = vorlage.replace("{WERKSTOFF}", werkstoff).replace("{ZWECK}", zweck)
print(prompt)
# Out:
# Fasse das Datenblatt zu S235JR zusammen. Zielgruppe: Konstruktions-Entwurf einer Rahmen-Schweissbaugruppe.

# %% [markdown]
# ## Mini-Challenge – `normiere_begriff`

# %%
def normiere_begriff(text):
    return text.strip().lower().replace("-", "_")

assert normiere_begriff("  CNC-Fraese  ") == "cnc_fraese"
assert normiere_begriff("Vorschub-Geschwindigkeit") == "vorschub_geschwindigkeit"
assert normiere_begriff("\tWerkzeug-Halter\n") == "werkzeug_halter"
print("✅ alle Tests gruen")
# Out:
# ✅ alle Tests gruen
