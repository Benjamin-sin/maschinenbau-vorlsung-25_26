# %% [markdown]
# # V15 – Netzwerktechnik: Aufgaben
#
# ## 🎯 Lernziele
# Nach diesem Notebook hast du …
# - eine CSV-Datei mit Netzwerkpaketen eingelesen und ausgewertet,
# - kleine Hilfsfunktionen zur Validierung von Port und IP-Adresse geschrieben,
# - eine JSON-Konfiguration auswertend durchlaufen,
# - einen OPC-UA-XML-Baum geparst und einen Aggregatwert berechnet.
#
# ## ⏱️ Zeitbudget
# Ca. 90 Minuten für alle fünf Aufgaben.
#
# ## 🧭 TL;DR
# Fünf Aufgaben steigenden Anspruchs: drei einfache Aufwärmer (⭐) und zwei mittlere Aufgaben (⭐⭐) mit PAP. Alle Aufgaben laufen offline auf den Dateien im V15-Ordner.
#
# ## 📦 Voraussetzungen
# - [00_python_recap.ipynb](00_python_recap.ipynb)
# - [01_theorie.ipynb](01_theorie.ipynb)
# - [02_praxis.ipynb](02_praxis.ipynb)

# %% [markdown]
# ## A1 ⭐ – Paket-Anzahl zählen
#
# **Kontext:** Die Datei `netzwerk_pakete.csv` enthält einen Mitschnitt von Netzwerkpaketen aus einer Produktionshalle. Die erste Zeile ist die Kopfzeile mit Spaltennamen.
#
# **Aufgabe:** Ermittle die Anzahl der **Datensätze** (also ohne die Kopfzeile) und speichere das Ergebnis in der Variablen `paket_anzahl`.
#
# **Erwartete Ausgabe:** `paket_anzahl` ist `100`.

# %%
# TODO: Datei öffnen, Zeilen zählen, Kopfzeile abziehen
paket_anzahl = 0

print(f"Anzahl Pakete: {paket_anzahl}")
# Out:
# Anzahl Pakete: 0

# %%
# ▶️ Selbstkontrolle
try:
    assert paket_anzahl == 100, f"Erwartet 100, bekommen {paket_anzahl}"
    print("✅ A1 richtig gelöst.")
except AssertionError as e:
    print(f"❌ Noch nicht ganz: {e}")
except NameError:
    print("❌ Die Variable `paket_anzahl` existiert noch nicht.")
# Out:
# ❌ Noch nicht ganz: Erwartet 100, bekommen 0

# %% [markdown]
# ## A2 ⭐ – Port prüfen
#
# **Kontext:** Beim Einlesen von Konfigurationsdateien muss ein Port-String auf Plausibilität geprüft werden.
#
# **Aufgabe:** Schreibe eine Funktion `port_valide(port_str)`, die genau dann `True` liefert, wenn der String nur aus Ziffern besteht und die Zahl im Bereich `1 <= port <= 65535` liegt. Sonst `False`.
#
# **Erwartete Ausgabe:** Die Asserts laufen durch.

# %%
def port_valide(port_str):
    # TODO: Ziffern-Prüfung und Bereichsprüfung
    return False

# %%
# ▶️ Selbstkontrolle
try:
    assert port_valide("80") is True
    assert port_valide("65535") is True
    assert port_valide("abc") is False
    assert port_valide("70000") is False
    assert port_valide("0") is False
    print("✅ A2 richtig gelöst.")
except AssertionError as e:
    print(f"❌ Noch nicht ganz: {e}")
except NameError:
    print("❌ Die Funktion `port_valide` existiert noch nicht.")
# Out:
# ❌ Noch nicht ganz:

# %% [markdown]
# ## A3 ⭐ – IP-Adresse parsen
#
# **Kontext:** Oft musst du eine IPv4-Adresse in ihre Oktette zerlegen, z. B. um das Subnetz zu vergleichen.
#
# **Aufgabe:** Schreibe eine Funktion `ip_teile(ip_str)`, die einen String wie `"192.168.1.10"` entgegennimmt und eine Liste der vier Oktette als **Integer** zurückgibt.
#
# **Erwartete Ausgabe:** `ip_teile("192.168.1.10")` liefert `[192, 168, 1, 10]`.

# %%
def ip_teile(ip_str):
    # TODO: an '.' splitten und jedes Element in int wandeln
    return []

# %%
# ▶️ Selbstkontrolle
try:
    assert ip_teile("192.168.1.10") == [192, 168, 1, 10]
    assert ip_teile("10.0.0.1") == [10, 0, 0, 1]
    ergebnis = ip_teile("192.168.10.100")
    assert all(isinstance(x, int) for x in ergebnis), "Alle Elemente müssen int sein"
    print("✅ A3 richtig gelöst.")
except AssertionError as e:
    print(f"❌ Noch nicht ganz: {e}")
except NameError:
    print("❌ Die Funktion `ip_teile` existiert noch nicht.")
# Out:
# ❌ Noch nicht ganz:

# %% [markdown]
# ## A4 ⭐⭐ – Kritische Maschinen zählen
#
# **Kontext:** Die JSON-Datei `maschinenkommunikation.json` enthält Betriebsdaten von zehn Produktionsmaschinen. Als **kritisch** gilt eine Maschine, wenn ihre **durchschnittliche Latenz > 15 ms** ODER ihre **Fehlerrate > 0.2 %** ist. Der zugehörige Programmablaufplan zeigt die Schleifenstruktur.
#
# **Aufgabe:** Lies die JSON-Datei ein, durchlaufe alle Einträge in `daten["maschinen"]`, prüfe die genannte Bedingung und zähle die Treffer in der Variablen `kritisch_anzahl`.
#
# **Erwartete Ausgabe:** `kritisch_anzahl` ist `3`.

# %%
from IPython.display import Markdown, display
with open("diagramme/aufgabe_4_pap.mmd", encoding="utf-8") as f:
    display(Markdown(f"```mermaid\n{f.read()}\n```"))
# Out:
# ```mermaid
# flowchart TD
#     S(["Start"]) --> L["JSON-Datei laden"]
#     L --> IT["Leere Liste 'kritisch'"]
#     IT --> F{"Fuer jede Maschine"}
#     F -->|"ja"| C{"Latenz > 15 ms<br/>ODER Fehlerrate > 0.2%?"}
#     C -->|"ja"| A["Maschine anhaengen"]
#     C -->|"nein"| F
#     A --> F
#     F -->|"fertig"| P["Liste ausgeben"]
#     P --> E(["Ende"])
#
# ```

# %%
import json

with open("maschinenkommunikation.json", encoding="utf-8") as f:
    daten = json.load(f)

# TODO: Schleife über daten["maschinen"], Bedingung prüfen, zählen
kritisch_anzahl = 0

print(f"Kritische Maschinen: {kritisch_anzahl}")
# Out:
# Kritische Maschinen: 0

# %%
# ▶️ Selbstkontrolle
try:
    assert kritisch_anzahl == 3, f"Erwartet 3, bekommen {kritisch_anzahl}"
    print("✅ A4 richtig gelöst.")
except AssertionError as e:
    print(f"❌ Noch nicht ganz: {e}")
except NameError:
    print("❌ Die Variable `kritisch_anzahl` existiert noch nicht.")
# Out:
# ❌ Noch nicht ganz: Erwartet 3, bekommen 0

# %% [markdown]
# ## A5 ⭐⭐ – Höchster OPC-UA-Messwert
#
# **Kontext:** Die Datei `opc_ua_daten.xml` simuliert einen Abzug aus einem OPC-UA-Adressraum. Die Struktur ist:
#
# ```
# <opc_ua_server>
#   <nodes>
#     <node>
#       <variables>
#         <variable>
#           <data_type>Double</data_type>
#           <value>2450.5</value>
#           ...
#         </variable>
# ```
#
# **Aufgabe:** Parse die XML mit `xml.etree.ElementTree`. Durchlaufe alle `variable`-Elemente, nimm **nur die Variablen mit `data_type == "Double"`**, wandle deren `value` in `float` um und speichere den höchsten gefundenen Wert in `hoechster_wert`.
#
# **Erwartete Ausgabe:** `hoechster_wert` ist `8500.0` (Spindeldrehzahl der Fräsmaschine).

# %%
from IPython.display import Markdown, display
with open("diagramme/aufgabe_5_pap.mmd", encoding="utf-8") as f:
    display(Markdown(f"```mermaid\n{f.read()}\n```"))
# Out:
# ```mermaid
# flowchart TD
#     S(["Start"]) --> P["XML parsen"]
#     P --> L["Leere Liste 'werte'"]
#     L --> IT{"Fuer jede Variable"}
#     IT -->|"ja"| C{"browse_name == 'Drehzahl'?"}
#     C -->|"ja"| K{"value ist Zahl?"}
#     K -->|"ja"| A["Wert anhaengen"]
#     K -->|"nein"| IT
#     C -->|"nein"| IT
#     A --> IT
#     IT -->|"fertig"| M["Mittelwert + Max berechnen"]
#     M --> E(["Ende"])
#
# ```

# %%
import xml.etree.ElementTree as ET

baum = ET.parse("opc_ua_daten.xml")
wurzel = baum.getroot()

# TODO: über .findall('.//variable') iterieren und Maximum finden
hoechster_wert = 0.0

print(f"Höchster Wert: {hoechster_wert}")
# Out:
# Höchster Wert: 0.0

# %%
# ▶️ Selbstkontrolle
try:
    assert hoechster_wert == 8500.0, f"Erwartet 8500.0, bekommen {hoechster_wert}"
    print("✅ A5 richtig gelöst.")
except AssertionError as e:
    print(f"❌ Noch nicht ganz: {e}")
except NameError:
    print("❌ Die Variable `hoechster_wert` existiert noch nicht.")
# Out:
# ❌ Noch nicht ganz: Erwartet 8500.0, bekommen 0.0

# %% [markdown]
# ## ✅ Zusammenfassung
# - CSV-Dateien werden zeilenweise gelesen, die Kopfzeile zählt nicht zu den Daten.
# - Eine Port-Prüfung braucht Zeichen- **und** Bereichsprüfung.
# - JSON ist ein geschachteltes Dictionary, das per `json.load` direkt in Python-Objekte wird.
# - OPC-UA-XML durchläuft man mit `ET.parse(...)` und `findall(...)`.
#
# ## ➡️ Nächster Schritt
# Weiter mit V16 – Netzwerktechnik Teil 2.
