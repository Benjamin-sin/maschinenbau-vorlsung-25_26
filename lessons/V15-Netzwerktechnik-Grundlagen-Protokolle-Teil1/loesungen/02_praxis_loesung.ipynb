# %% [markdown]
# # V15 – Lösungen zu 02_praxis
#
# Vollständige Lösungen zu den Fill-in-Blanks und der Mini-Challenge aus [../02_praxis.ipynb](../02_praxis.ipynb).

# %% [markdown]
# ## 5. Fill-in-Blank 1 – Host und Port trennen

# %%
adresse = "scada.halle.a:502"
teile = adresse.split(":")
host = teile[0]
port = int(teile[1])

try:
    assert host == "scada.halle.a"
    assert port == 502
    assert isinstance(port, int)
    print("✅ Host und Port korrekt zerlegt.")
except AssertionError as e:
    print(f"❌ Noch nicht ganz: {e}")
except NameError:
    print("❌ `host` oder `port` fehlt noch.")
# Out:
# ✅ Host und Port korrekt zerlegt.

# %% [markdown]
# ## 6. Fill-in-Blank 2 – Protokoll aus URL ableiten

# %%
url = "https://mes.halle.a/api/status"
ist_sicher = url.startswith("https")

try:
    assert ist_sicher is True
    print("✅ Protokoll richtig erkannt.")
except AssertionError as e:
    print(f"❌ Noch nicht ganz: {e}")
except NameError:
    print("❌ Die Variable `ist_sicher` existiert noch nicht.")
# Out:
# ✅ Protokoll richtig erkannt.

# %% [markdown]
# ## 7. Fill-in-Blank 3 – Zeile säubern

# %%
rohzeile = "   Modbus TCP\n"
sauber = rohzeile.strip()

try:
    assert sauber == "Modbus TCP"
    print("✅ Whitespace korrekt entfernt.")
except AssertionError as e:
    print(f"❌ Noch nicht ganz: {e}")
except NameError:
    print("❌ Die Variable `sauber` existiert noch nicht.")
# Out:
# ✅ Whitespace korrekt entfernt.

# %% [markdown]
# ## 9. Mini-Challenge – `ist_valide_port`
#
# Die Funktion prüft zuerst mit `.isdigit()`, dass nur Ziffern enthalten sind (schließt leeren String, Minus, Buchstaben und Whitespace aus), und wandelt dann erst in `int` um, um den gültigen Bereich zu prüfen. Diese Reihenfolge ist wichtig, weil `int("abc")` sonst einen `ValueError` werfen würde.

# %%
def ist_valide_port(port_str):
    if not port_str.isdigit():
        return False
    port = int(port_str)
    return 1 <= port <= 65535

try:
    assert ist_valide_port("80") is True
    assert ist_valide_port("65535") is True
    assert ist_valide_port("abc") is False
    assert ist_valide_port("70000") is False
    assert ist_valide_port("0") is False
    assert ist_valide_port("") is False
    print("✅ Challenge gelöst.")
except AssertionError as e:
    print(f"❌ Noch nicht ganz: {e}")
except NameError:
    print("❌ Die Funktion `ist_valide_port` existiert noch nicht.")
# Out:
# ✅ Challenge gelöst.
