# %% [markdown]
# # V17 – Kryptografie: Aufgaben
#
# ## 🎯 Lernziele
# Nach diesem Notebook hast du …
# - eine Funktion geschrieben, die den **ASCII-Code** eines Zeichens liefert,
# - einen einzelnen Buchstaben per **Caesar-Formel** verschoben,
# - einen vollständigen Text **Caesar-verschlüsselt** und **entschlüsselt**,
# - einen **Brute-Force-Dekodierer** implementiert, der alle 25 möglichen Klartexte liefert.
#
# ## ⏱️ Zeitbudget
# Ca. 25 Minuten für alle fünf Aufgaben.
#
# ## 🧭 TL;DR
# Fünf Aufgaben steigenden Anspruchs: drei einfache (⭐) und zwei mittlere (⭐⭐) mit **Programmablaufplan**. Alle Asserts prüfen sich selbst, sodass du sofort Feedback bekommst.
#
# ## 📦 Voraussetzungen
# - [00_python_recap.ipynb](00_python_recap.ipynb)
# - [01_theorie.ipynb](01_theorie.ipynb)
# - [02_praxis.ipynb](02_praxis.ipynb)

# %% [markdown]
# ## A1 ⭐ – ASCII-Code
#
# **Kontext:** Wir brauchen für Caesar eine kleine Hilfe, die den ASCII-Code eines Zeichens liefert. Das ist nichts anderes als ein Wrapper um `ord()`.
#
# **Aufgabe:** Schreibe eine Funktion `code_von(zeichen)`, die den ASCII-Code des übergebenen Zeichens zurückgibt.
#
# **Erwartete Ausgabe:** Die Asserts unten laufen durch, insbesondere `code_von("A") == 65`, `code_von("Z") == 90` und `code_von(" ") == 32`.

# %%
def code_von(zeichen):
    # TODO: Gib den ASCII-Code von `zeichen` zurück (Tipp: ord(...))
    return 0

# %%
# ▶️ Selbstkontrolle A1
try:
    assert code_von("A") == 65, f"code_von('A') soll 65 sein, ist {code_von('A')}"
    assert code_von("Z") == 90, f"code_von('Z') soll 90 sein, ist {code_von('Z')}"
    assert code_von(" ") == 32, f"code_von(' ') soll 32 sein, ist {code_von(' ')}"
    assert code_von("a") == 97, f"code_von('a') soll 97 sein, ist {code_von('a')}"
    print("✅ A1 richtig gelöst.")
except AssertionError as e:
    print(f"❌ Noch nicht ganz: {e}")
except NameError:
    print("❌ Die Funktion `code_von` existiert noch nicht.")
# Out:
# ❌ Noch nicht ganz: code_von('A') soll 65 sein, ist 0

# %% [markdown]
# ## A2 ⭐ – Buchstabe verschieben
#
# **Kontext:** Das Herzstück der Caesar-Chiffre ist die Verschiebung eines **einzelnen Großbuchstabens** um `k` Schritte. Dabei rollt der Buchstabe am Alphabet-Ende wieder nach vorne.
#
# **Aufgabe:** Schreibe eine Funktion `verschiebe(buchstabe, k)`, die einen Großbuchstaben (A–Z) um `k` Schritte nach rechts verschiebt. Nutze die Formel `(pos + k) % 26`. Du darfst annehmen, dass der Eingabe-Buchstabe wirklich ein Großbuchstabe ist.
#
# **Erwartete Ausgabe:** `verschiebe("A", 3) == "D"`, `verschiebe("Z", 1) == "A"`, `verschiebe("H", 3) == "K"`.

# %%
def verschiebe(buchstabe, k):
    # TODO: ord(...) - 65, + k, % 26, + 65, chr(...)
    return "A"

# %%
# ▶️ Selbstkontrolle A2
try:
    assert verschiebe("A", 3) == "D", f"verschiebe('A',3) soll 'D' sein, ist '{verschiebe('A', 3)}'"
    assert verschiebe("Z", 1) == "A", f"verschiebe('Z',1) soll 'A' sein, ist '{verschiebe('Z', 1)}'"
    assert verschiebe("H", 3) == "K", f"verschiebe('H',3) soll 'K' sein, ist '{verschiebe('H', 3)}'"
    assert verschiebe("M", 13) == "Z", f"verschiebe('M',13) soll 'Z' sein, ist '{verschiebe('M', 13)}'"
    assert verschiebe("A", 0) == "A", "k=0 darf nichts verändern"
    print("✅ A2 richtig gelöst.")
except AssertionError as e:
    print(f"❌ Noch nicht ganz: {e}")
except NameError:
    print("❌ Die Funktion `verschiebe` existiert noch nicht.")
# Out:
# ❌ Noch nicht ganz: verschiebe('A',3) soll 'D' sein, ist 'A'

# %% [markdown]
# ## A3 ⭐ – Caesar verschlüsseln
#
# **Kontext:** Jetzt baust du aus `verschiebe` eine komplette Verschlüsselung, die auch Sätze mit Leerzeichen versteht.
#
# **Aufgabe:** Schreibe eine Funktion `caesar_ver(text, k)`, die jeden **Großbuchstaben** im Text um `k` verschiebt und alle anderen Zeichen (Leerzeichen, Satzzeichen, Ziffern) **unverändert** lässt.
#
# **Erwartete Ausgabe:** `caesar_ver("HALLO WELT", 3) == "KDOOR ZHOW"`.

# %%
def caesar_ver(text, k):
    # TODO: Schleife über text, Großbuchstaben verschieben, Rest unverändert lassen
    return ""

# %%
# ▶️ Selbstkontrolle A3
try:
    assert caesar_ver("HALLO WELT", 3) == "KDOOR ZHOW", \
        f"Erwartet 'KDOOR ZHOW', bekommen '{caesar_ver('HALLO WELT', 3)}'"
    assert caesar_ver("ABCXYZ", 1) == "BCDYZA", \
        f"Umlauf klappt nicht: {caesar_ver('ABCXYZ', 1)}"
    assert caesar_ver("HALLO, WELT!", 3) == "KDOOR, ZHOW!", \
        f"Satzzeichen müssen unverändert bleiben: {caesar_ver('HALLO, WELT!', 3)}"
    assert caesar_ver("", 5) == "", "Leerer Text muss leer bleiben"
    print("✅ A3 richtig gelöst.")
except AssertionError as e:
    print(f"❌ Noch nicht ganz: {e}")
except NameError:
    print("❌ Die Funktion `caesar_ver` existiert noch nicht.")
# Out:
# ❌ Noch nicht ganz: Erwartet 'KDOOR ZHOW', bekommen ''

# %% [markdown]
# ## A4 ⭐⭐ – Caesar entschlüsseln
#
# **Kontext:** Entschlüsseln ist das Gegenstück zu A3. Mathematisch läuft es auf eine Verschiebung um `-k` hinaus, oder äquivalent um `(26 - k) % 26` Schritte.
#
# **Aufgabe:** Schreibe eine Funktion `caesar_ent(text, k)`, die einen Caesar-Geheimtext mit Schlüssel `k` entschlüsselt. Du darfst `caesar_ver` aus A3 wiederverwenden.
#
# **Erwartete Ausgabe:** `caesar_ent("KDOOR ZHOW", 3) == "HALLO WELT"`.
#
# Studiere zuerst den **Programmablaufplan** in der nächsten Zelle.

# %%
from IPython.display import Markdown, display
with open("diagramme/aufgabe_4_pap.mmd", encoding="utf-8") as f:
    display(Markdown(f"```mermaid\n{f.read()}\n```"))
# Out:
# ```mermaid
# flowchart TD
#     S(["Start: text, k"]) --> I["Schluessel umkehren:<br/>k_ent = (26 - k) % 26"]
#     I --> R["Ergebnis = '' (leerer String)"]
#     R --> F{"Fuer jedes Zeichen z<br/>in text"}
#     F -- "ja" --> C{"z ist<br/>Grossbuchstabe A-Z?"}
#     C -- "ja" --> V["pos = ord(z) - 65<br/>neu = (pos + k_ent) % 26<br/>z_neu = chr(neu + 65)"]
#     C -- "nein" --> U["z_neu = z<br/>(unveraendert)"]
#     V --> A["Ergebnis = Ergebnis + z_neu"]
#     U --> A
#     A --> F
#     F -- "fertig" --> O["Ergebnis zurueckgeben"]
#     O --> E(["Ende"])
#
# ```

# %%
def caesar_ent(text, k):
    # TODO: Rückwärts verschieben, z. B. caesar_ver(text, -k)
    return ""

# %%
# ▶️ Selbstkontrolle A4
try:
    assert caesar_ent("KDOOR ZHOW", 3) == "HALLO WELT", \
        f"Erwartet 'HALLO WELT', bekommen '{caesar_ent('KDOOR ZHOW', 3)}'"
    assert caesar_ent("BCDYZA", 1) == "ABCXYZ", \
        f"Umlauf rückwärts falsch: {caesar_ent('BCDYZA', 1)}"
    assert caesar_ent(caesar_ver("MASCHINE AN", 9), 9) == "MASCHINE AN", \
        "Roundtrip ver/ent mit k=9 muss identisch sein"
    assert caesar_ent("KDOOR, ZHOW!", 3) == "HALLO, WELT!", \
        "Satzzeichen müssen unverändert bleiben"
    print("✅ A4 richtig gelöst.")
except AssertionError as e:
    print(f"❌ Noch nicht ganz: {e}")
except NameError:
    print("❌ Die Funktion `caesar_ent` existiert noch nicht.")
# Out:
# ❌ Noch nicht ganz: Erwartet 'HALLO WELT', bekommen ''

# %% [markdown]
# ## A5 ⭐⭐ – Brute-Force-Dekodierer
#
# **Kontext:** Caesar hat nur 25 mögliche Schlüssel. Ein Angreifer probiert einfach alle durch und wählt das lesbare Ergebnis aus.
#
# **Aufgabe:** Schreibe eine Funktion `brute_force(geheim)`, die eine **Liste mit 25 Elementen** zurückgibt. An Index `i` (0-basiert) steht das Ergebnis der Entschlüsselung mit Schlüssel `i + 1`. Du darfst `caesar_ent` aus A4 wiederverwenden.
#
# **Erwartete Ausgabe:** `brute_force("KDOOR ZHOW")` hat Länge 25, und das Element an Index 2 (entspricht Schlüssel 3) ist `"HALLO WELT"`.
#
# Studiere zuerst den **Programmablaufplan** in der nächsten Zelle.

# %%
from IPython.display import Markdown, display
with open("diagramme/aufgabe_5_pap.mmd", encoding="utf-8") as f:
    display(Markdown(f"```mermaid\n{f.read()}\n```"))
# Out:
# ```mermaid
# flowchart TD
#     S(["Start: geheim"]) --> L["ergebnisse = [] (leere Liste)"]
#     L --> K["k = 1"]
#     K --> D["klartext = caesar_ent(geheim, k)"]
#     D --> A["ergebnisse anhaengen:<br/>klartext"]
#     A --> C{"k < 25?"}
#     C -- "ja" --> I["k = k + 1"]
#     I --> D
#     C -- "nein" --> O["ergebnisse zurueckgeben"]
#     O --> E(["Ende"])
#
# ```

# %%
def brute_force(geheim):
    # TODO: Für k=1..25 caesar_ent(geheim, k) ausrechnen und in einer Liste sammeln
    return []

# %%
# ▶️ Selbstkontrolle A5
try:
    ergebnisse = brute_force("KDOOR ZHOW")
    assert isinstance(ergebnisse, list), "brute_force muss eine Liste zurückgeben"
    assert len(ergebnisse) == 25, f"Liste muss 25 Einträge haben, hat {len(ergebnisse)}"
    assert ergebnisse[2] == "HALLO WELT", \
        f"Index 2 (Schlüssel 3) soll 'HALLO WELT' sein, ist '{ergebnisse[2]}'"
    assert ergebnisse[0] == "JCNNQ YGNV", \
        f"Index 0 (Schlüssel 1) soll 'JCNNQ YGNV' sein, ist '{ergebnisse[0]}'"
    print("✅ A5 richtig gelöst.")
except AssertionError as e:
    print(f"❌ Noch nicht ganz: {e}")
except NameError:
    print("❌ Die Funktion `brute_force` existiert noch nicht.")
# Out:
# ❌ Noch nicht ganz: Liste muss 25 Einträge haben, hat 0

# %% [markdown]
# ## ✅ Zusammenfassung
#
# - `code_von` gibt per `ord()` den ASCII-Code eines Zeichens zurück.
# - `verschiebe` realisiert die Caesar-Formel `(pos + k) % 26` für einen Buchstaben.
# - `caesar_ver` und `caesar_ent` verschlüsseln und entschlüsseln ganze Texte und lassen Sonderzeichen unberührt.
# - `brute_force` zeigt, warum Caesar nicht sicher ist: 25 Versuche genügen.
#
# ## ➡️ Nächster Schritt
# Vergleiche deine Lösungen im Ordner [loesungen/](loesungen/). In **V18** geht es weiter mit modernen Verfahren (Hashes, HMAC, symmetrische & asymmetrische Verfahren in Python).
