# %% [markdown]
# # VXX – <Thema>: Theorie
#
# ## 🎯 Lernziele
# Nach diesem Notebook kannst du …
# - …
# - …
# - …
#
# ## ⏱️ Zeitbudget
# Ca. XX Minuten.
#
# ## 🧭 TL;DR
# <2–3 Sätze mit dem Kern der Theorie.>
#
# ## 📦 Voraussetzungen
# - …

# %% [markdown]
# ## 1. Konzept A
#
# Erklärung in 1–2 Absätzen. Konkretes Beispiel aus dem Ingenieur-Alltag, ggf. Analogie.
# Erlaubt und erwünscht: ein Konzept aus mehreren Blickwinkeln beleuchten.
#
# [Diagramm-Quelle](diagramme/01_konzept_a.mmd)

# %%
# Diagramm aus externer .mmd-Datei laden und anzeigen
from IPython.display import Markdown, display
with open("diagramme/01_konzept_a.mmd", encoding="utf-8") as f:
    display(Markdown(f"```mermaid\n{f.read()}\n```"))

# %%
# Mini-Demo zu Konzept A – einfach ausführen und beobachten
print("Demo-Ausgabe")

# %% [markdown]
# ### 1.1 Vertiefung
#
# Weiterer Absatz, der das Konzept aus anderem Blickwinkel zeigt (z. B. Ingenieur-Bezug,
# historischer Kontext, typischer Anfängerfehler).

# %% [markdown]
# > 💡 **Weiterführend** (optional)
# >
# > Details für Interessierte, nicht prüfungsrelevant.

# %% [markdown]
# ## 2. Konzept B
#
# …

# %% [markdown]
# ## Selbst-Check (Klick zum Aufklappen)
#
# <details>
# <summary>❓ Frage 1</summary>
#
# Antwort 1.
# </details>
#
# <details>
# <summary>❓ Frage 2</summary>
#
# Antwort 2.
# </details>

# %% [markdown]
# ## ✅ Zusammenfassung
# - …
# - …
#
# ## ➡️ Nächster Schritt
# Weiter mit [02_praxis.ipynb](02_praxis.ipynb).
