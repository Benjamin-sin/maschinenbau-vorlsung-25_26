# %% [markdown]
# # VXX – <Thema>: Praxis
#
# ## 🎯 Lernziele
# Nach diesem Notebook kannst du …
# - …
# - …
#
# ## ⏱️ Zeitbudget
# Ca. XX Minuten.
#
# ## 🧭 TL;DR
# <1–2 Sätze.>
#
# ## 🚦 So gehst du vor
# - Führe jede Zelle aus (Shift+Enter).
# - Ändere Werte, probiere aus.
# - Zellen mit `# TODO:` sind für dich zum Selbst-Ausfüllen.

# %% [markdown]
# ## Schritt 1 – <Mikro-Konzept>
#
# Kurze Einführung in einen einzelnen Gedanken (max. 2 Sätze).

# %%
# Beispiel – einfach ausführen
x = 10
y = x * 2
print(y)

# %% [markdown]
# ### ✏️ Jetzt du
#
# Ergänze unten den fehlenden Code.

# %%
# TODO: Berechne den dreifachen Wert von x und speichere ihn in `dreifach`.
x = 10
dreifach = ...  # <-- dein Code
print(dreifach)

# %%
# ▶️ Selbstkontrolle – einfach ausführen
try:
    assert dreifach == 30, f"Erwartet 30, bekommen: {dreifach}"
    print("✅ Richtig!")
except AssertionError as e:
    print(f"❌ Noch nicht ganz: {e}")
except NameError:
    print("❌ Die Variable `dreifach` existiert noch nicht.")

# %% [markdown]
# ## Schritt 2 – <nächstes Mikro-Konzept>
#
# …

# %% [markdown]
# ## 🎯 Mini-Challenge
#
# Aufgabe in einer Zeile beschrieben. Schreibe den Code in die Zelle darunter.

# %%
# TODO: …
ergebnis = ...

# %%
try:
    assert ergebnis == ..., f"Erwartet …, bekommen: {ergebnis}"
    print("✅ Stark!")
except AssertionError as e:
    print(f"❌ Noch nicht ganz: {e}")
except NameError:
    print("❌ Variable `ergebnis` fehlt.")

# %% [markdown]
# ## ✅ Zusammenfassung
# - …
#
# ## ➡️ Nächster Schritt
# Weiter mit [03_aufgaben.ipynb](03_aufgaben.ipynb).
