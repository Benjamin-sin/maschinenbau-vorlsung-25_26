# %% [markdown]
# # VXX – <Thema>: Aufgaben
#
# ## 🎯 Lernziele
# Du überprüfst, ob du die Inhalte dieser Vorlesung selbstständig anwenden kannst.
#
# ## ⏱️ Zeitbudget
# Ca. XX Minuten.
#
# ## 📋 Aufgabenübersicht
# | # | Titel | Schwierigkeit |
# |---|-------|---------------|
# | 1 | … | ⭐ |
# | 2 | … | ⭐ |
# | 3 | … | ⭐ |
# | 4 | … | ⭐⭐ |
# | 5 | … | ⭐⭐ |
#
# ## 🚦 Vorgehen
# - Löse jede Aufgabe in der Code-Zelle darunter.
# - Führe danach die Selbstkontroll-Zelle aus. Beim ersten Durchlauf darf ❌ erscheinen – das ist der Startzustand.
# - Erst **selbst probieren**, dann ggf. in [loesungen/](loesungen/) nachschauen.

# %% [markdown]
# ## Aufgabe 1 ⭐ – <Titel>
#
# **Kontext:** <Ein Satz, worum es geht.>
#
# **Aufgabe:** <Was genau ist zu tun?>
#
# **Erwartete Ausgabe:**
# ```
# …
# ```

# %%
# TODO: Löse die Aufgabe.
# Der Starter-Code gibt aktuell einen falschen Wert zurück – passe ihn an.
ergebnis_1 = 0  # <-- dein Code hier
print(ergebnis_1)

# %%
# ▶️ Selbstkontrolle Aufgabe 1 – einfach ausführen
try:
    assert ergebnis_1 == 42, f"Erwartet 42, bekommen: {ergebnis_1}"
    print("✅ Aufgabe 1 gelöst.")
except AssertionError as e:
    print(f"❌ Noch nicht ganz: {e}")
except NameError:
    print("❌ Variable `ergebnis_1` fehlt.")

# %% [markdown]
# ## Aufgabe 2 ⭐ – <Titel>
#
# <Kopiere den 3-Zellen-Block von Aufgabe 1: Markdown-Beschreibung, Starter-Code-Zelle, Selbstkontroll-Zelle. Passe Variablennamen (`ergebnis_2`), Starter-Wert und assert-Bedingung an.>

# %% [markdown]
# ## Aufgabe 3 ⭐ – <Titel>
#
# <wie Aufgabe 1, mit `ergebnis_3`>

# %% [markdown]
# ## Aufgabe 4 ⭐⭐ – <Titel>
#
# <etwas anspruchsvoller, `ergebnis_4`>

# %% [markdown]
# ## Aufgabe 5 ⭐⭐ – <Titel>
#
# <wie oben, `ergebnis_5`>

# %% [markdown]
# ## ✅ Geschafft!
# Wenn alle asserts grün sind, beherrschst du die Inhalte dieser Vorlesung gut genug.
#
# Lösungen zum Vergleich: [loesungen/03_aufgaben_loesung.ipynb](loesungen/03_aufgaben_loesung.ipynb).
