# %% [markdown]
# # VXX – <Thema>: Lösungen
#
# Dieses Notebook enthält Musterlösungen zu [../03_aufgaben.ipynb](../03_aufgaben.ipynb).
#
# **⚠️ Bitte zuerst selbst versuchen!** Lernen passiert beim Versuch, nicht beim Lesen.

# %% [markdown]
# ## Aufgabe 1 ⭐ – <Titel>
#
# **Lösungsidee:** <Kurzer Kommentar, wie man vorgeht.>

# %%
# Musterlösung Aufgabe 1
ergebnis = 42
print(ergebnis)

# %%
assert ergebnis == 42
print("✅")
